# %%
# d=[]
# e=dict()
# for n in range(10000):
#     g=str(n*(n+1)//2)
#     if len(g)==4 and int(g[2:4])>9:
#         d.append(g)
# e[3]=d

# d=[]
# for n in range(10000):
#     g=str(n*n)
#     if len(g)==4 and int(g[2:4])>9:
#         d.append(g)
# e[4]=d

# d=[]
# for n in range(10000):
#     g=str(n*(3*n-1)//2)
#     if len(g)==4 and int(g[2:4])>9:
#         d.append(g)
# e[5]=d

# d=[]
# for n in range(10000):
#     g=str(n*(2*n-1))
#     if len(g)==4 and int(g[2:4])>9:
#         d.append(g)
# e[6]=d

# d=[]
# for n in range(10000):
#     g=str(n*(5*n-3)//2)
#     if len(g)==4 and int(g[2:4])>9:
#         d.append(g)
# e[7]=d

# d=[]
# for n in range(10000):
#     g=str(n*(3*n-2))
#     if len(g)==4  and int(g[2:4])>9:
#         d.append(g)
# e[8]=d
# for i,j in e.items():
    
#     print(i,j)
#     print()

# %%
import itertools
# a=['1035', '1081', '1128', '1176', '1225', '1275', '1326', '1378', '1431', '1485', '1540', '1596', '1653', '1711', '1770', '1830', '1891', '1953', '2016', '2080', '2145', '2211', '2278', '2346', '2415', '2485', '2556', '2628', '2775', '2850', '2926', '3081', '3160', '3240', '3321', '3486', '3570', '3655', '3741', '3828', '3916', '4095', '4186', '4278', '4371', '4465', '4560', '4656', '4753', '4851', '4950', '5050', '5151', '5253', '5356', '5460', '5565', '5671', '5778', '5886', '5995', '6216', '6328', '6441', '6555', '6670', '6786', '7021', '7140', '7260', '7381', '7626', '7750', '7875', '8128', '8256', '8385', '8515', '8646', '8778', '8911', '9045', '9180', '9316', '9453', '9591', '9730', '9870']

# b=['1024', '1089', '1156', '1225', '1296', '1369', '1444', '1521', '1681', '1764', '1849', '1936', '2025', '2116', '2916', '3025', '3136', '3249', '3364', '3481', '3721', '3844', '3969', '4096', '4225', '4356', '4489', '4624', '4761', '5041', '5184', '5329', '5476', '5625', '5776', '5929', '6084', '6241', '6561', '6724', '6889', '7056', '7225', '7396', '7569', '7744', '7921', '8281', '8464', '8649', '8836', '9025', '9216']

# c=['1080', '1162', '1247', '1335', '1426', '1520', '1617', '1717', '1820', '1926', '2035', '2147', '2262', '2380', '2625', '2752', '2882', '3015', '3151', '3290', '3432', '3577', '3725', '3876', '4030', '4187', '4347', '4510', '4676', '4845', '5017', '5192', '5370', '5551', '5735', '5922', '6112', '7315', '7526', '7740', '7957', '8177', '8626', '8855', '9087', '9322', '9560']

# d=['1035', '1128', '1225', '1326', '1431', '1540', '1653', '1770', '1891', '2016', '2145', '2278', '2415', '2556', '2850', '3160', '3321', '3486', '3655', '3828', '4186', '4371', '4560', '4753', '4950', '5151', '5356', '5565', '5778', '5995', '6216', '6441', '6670', '7140', '7381', '7626', '7875', '8128', '8385', '8646', '8911', '9180', '9453', '9730']

# e=['1071', '1177', '1288', '1525', '1651', '1782', '1918', '2059', '2356', '2512', '2673', '2839', '3010', '3186', '3367', '3553', '3744', '3940', '4141', '4347', '4558', '4774', '4995', '5221', '5452', '5688', '5929', '6175', '6426', '6682', '6943', '7480', '7756', '8037', '8323', '8614', '8910', '9211', '9517', '9828']

print(len(a),len(b),len(c),len(d),len(e))
# def permutations(elements):
#     if len(elements) <= 1:
#         yield elements
#         return
#     for perm in permutations(elements[1:]):
#         for i in range(len(elements)):
#             # nb elements[0:1] works in both string and list contexts
#             yield perm[:i] + elements[0:1] + perm[i:]
# d=permutations([a,b,c,d,e,f])
# ddd=next(d)  #[a,b,c,d,e,f]

# for xx in ddd:   #[[a,c,b],[c,b,a],[b,a,c],[a,b,c]]:
#     print(f'{xx}\n')
#     for yy in ddd:   #[[a,c,b],[c,b,a],[b,a,c],[a,b,c]]:
#         print(f'          {yy}')
#         if xx==yy:
#             print('\n','skip')    
#             continue
#         print()
#         for x in xx:
#             for y in yy:
#                 print(f' {x}   {y}')
#                 if x==y:
#                     print('\n','skip')    
#                     continue
#                 if i[2:4]==j[0:2]:
#                     print(f'{i}')
#                     print(f'   {j}')
#                 # for i in x[0:3]:
#                 #     for j in y[0:3]:
#                 #         print(i,j)
#             print('-------------------------------')

# def srt(cc):
#     aa=list(map(int,cc))
#     result = sorted(aa, key=lambda x: (x % 100, x))
#     return list(map(str,result))

# print(srt(c))
# for i in a:     
#     for j in b:    
#         
#             for k in c:
#                 if j[2:4]==k[0:2]:
#                     print(f'      {k}')
#                     if k[2:4]==i[0:2]:
#                         print("winner, winner, chicken dinner")
                    # for l in d:
                    #     if k[2:4]==l[0:2]:
                    #         print(f'         {l}')
                    #         for m in e:
                    #             if l[2:4]==m[0:2]:
                    #                 print(f'            {m}')
                    #                 for n in f:
                    #                     if m[2:4]==n[0:2]:
                    #                         print(f'               {n}')
                    #                         for o in a:
                    #                             if m[2:4]==n[0:2]:
                    #                                 print(f'               {o}')
    # print()

# %%
a=['1035', '1081', '1128', '1176', '1225', '1275', '1326', '1378', '1431', '1485', '1540', '1596', '1653', '1711', '1770', '1830', '1891', '1953', '2016', '2080', '2145', '2211', '2278', '2346', '2415', '2485', '2556', '2628', '2701', '2775', '2850', '2926', '3003', '3081', '3160', '3240', '3321', '3403', '3486', '3570', '3655', '3741', '3828', '3916', '4005', '4095', '4186', '4278', '4371', '4465', '4560', '4656', '4753', '4851', '4950', '5050', '5151', '5253', '5356', '5460', '5565', '5671', '5778', '5886', '5995', '6105', '6216', '6328', '6441', '6555', '6670', '6786', '6903', '7021', '7140', '7260', '7381', '7503', '7626', '7750', '7875', '8001', '8128', '8256', '8385', '8515', '8646', '8778', '8911', '9045', '9180', '9316', '9453', '9591', '9730', '9870']

b=['1024', '1089', '1156', '1225', '1296', '1369', '1444', '1521', '1600', '1681', '1764', '1849', '1936', '2025', '2116', '2209', '2304', '2401', '2500', '2601', '2704', '2809', '2916', '3025', '3136', '3249', '3364', '3481', '3600', '3721', '3844', '3969', '4096', '4225', '4356', '4489', '4624', '4761', '4900', '5041', '5184', '5329', '5476', '5625', '5776', '5929', '6084', '6241', '6400', '6561', '6724', '6889', '7056', '7225', '7396', '7569', '7744', '7921', '8100', '8281', '8464', '8649', '8836', '9025', '9216', '9409', '9604', '9801']

c= ['1001', '1080', '1162', '1247', '1335', '1426', '1520', '1617', '1717', '1820', '1926', '2035', '2147', '2262', '2380', '2501', '2625', '2752', '2882', '3015', '3151', '3290', '3432', '3577', '3725', '3876', '4030', '4187', '4347', '4510', '4676', '4845', '5017', '5192', '5370', '5551', '5735', '5922', '6112', '6305', '6501', '6700', '6902', '7107', '7315', '7526', '7740', '7957', '8177', '8400', '8626', '8855', '9087', '9322', '9560', '9801']

d= ['1035', '1128', '1225', '1326', '1431', '1540', '1653', '1770', '1891', '2016', '2145', '2278', '2415', '2556', '2701', '2850', '3003', '3160', '3321', '3486', '3655', '3828', '4005', '4186', '4371', '4560', '4753', '4950', '5151', '5356', '5565', '5778', '5995', '6216', '6441', '6670', '6903', '7140', '7381', '7626', '7875', '8128', '8385', '8646', '8911', '9180', '9453', '9730']

e= ['1071', '1177', '1288', '1404', '1525', '1651', '1782', '1918', '2059', '2205', '2356', '2512', '2673', '2839', '3010', '3186', '3367', '3553', '3744', '3940', '4141', '4347', '4558', '4774', '4995', '5221', '5452', '5688', '5929', '6175', '6426', '6682', '6943', '7209', '7480', '7756', '8037', '8323', '8614', '8910', '9211', '9517', '9828']

f= ['1045', '1160', '1281', '1408', '1541', '1680', '1825', '1976', '2133', '2296', '2465', '2640', '2821', '3008', '3201', '3400', '3605', '3816', '4033', '4256', '4485', '4720', '4961', '5208', '5461', '5720', '5985', '6256', '6533', '6816', '7105', '7400', '7701', '8008', '8321', '8640', '8965', '9296', '9633', '9976']

def srt(cc):
    aa=list(map(int,cc))
    result = sorted(aa, key=lambda x: (x % 100, x))
    return list(map(str,result))

g=set()
for i in [a,b,c,d,e,f]:
    for j in i:
        g.add(j)  
dd=srt(g)
# print(dd)


h=[]
for i in dd:
    for j in dd:
        if i[2:4]==j[0:2]:

            for k in dd:
                if j[2:4]==k[0:2]:

                    # if i[0:2]==k[2:4]:
                    #     print(i,j,k,'   ++  ',i[0:2],k[2:4],sum([int(i),int(j),int(k)]))
                    for l in dd:
                        if k[2:4]==l[0:2]:  

                            # if i[0:2]==l[2:4]:
                            #     # print(i,j,k,l,'   --  ',i[0:2],l[2:4],sum([int(i),int(j),int(k),int(l)])) 
                            for m in dd:
                                if l[2:4]==m[0:2]: 

                                    # if i[0:2]==m[2:4]:
                                    #     # print(i,j,k,l,m,'   --  ',i[0:2],m[2:4],sum([int(i),int(j),int(k),int(l),int(m)]))
                                    for n in dd:
                                        if m[2:4]==n[0:2]:
                                     
                                            # if i[0:2]==n[2:4]:
                                            #     # print(i,j,k,l,m,n,'   @@  ',i[0:2],n[2:4],sum([int(i),int(j),int(k),int(l),int(m),int(n)]))
                                            h.append([i,j,k,l,m,n])
print(h)
s=0
for j in h:
    for i in j:
        print(i)
        if i in a:
            s+=int(i)
        else:
            is_ok=False
        if i in b:
            s+=int(i)
        else:
            is_ok=False
        if i in c:
            s+=int(i)
        else:
            is_ok=False
        if i in d:
            s+=int(i)
        else:
            is_ok=False
        if i in e:
            s+=int(i)
        else:
            is_ok=False
        if i in f:
            s+=int(i)
        else:
            is_ok=False
if is_ok:
    print(s)
